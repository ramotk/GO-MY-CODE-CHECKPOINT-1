# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns
from math import inf

# %%
x= pd.read_csv('kc_house_data.csv')
x.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %%
x.isnull().sum()
# Out:
# id               0
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %%
x.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21613 non-null  int64
#  1   date           21613 non-null  object
#  2   price          21613 non-null  float64
#  3   bedrooms       21613 non-null  int64
#  4   bathrooms      21613 non-null  float64
#  5   sqft_living    21613 non-null  int64
#  6   sqft_lot       21613 non-null  int64
#  7   floors         21613 non-null  float64
#  8   waterfront     21613 non-null  int64
#  9   view           21613 non-null  int64
#  10  condition      21613 non-null  int64
#  11  grade          21613 non-null  int64
#  12  sqft_above     21613 non-null  int64
#  13  sqft_basement  21613 non-null  int64
#  14  yr_built       21613 non-null  int64
#  15  yr_renovated   21613 non-null  int64
#  16  zipcode        21613 non-null  int64
# ...

# %%
x.drop(['id', 'date'], axis=1, inplace=True)

# %%
x.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 19 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   price          21613 non-null  float64
#  1   bedrooms       21613 non-null  int64
#  2   bathrooms      21613 non-null  float64
#  3   sqft_living    21613 non-null  int64
#  4   sqft_lot       21613 non-null  int64
#  5   floors         21613 non-null  float64
#  6   waterfront     21613 non-null  int64
#  7   view           21613 non-null  int64
#  8   condition      21613 non-null  int64
#  9   grade          21613 non-null  int64
#  10  sqft_above     21613 non-null  int64
#  11  sqft_basement  21613 non-null  int64
#  12  yr_built       21613 non-null  int64
#  13  yr_renovated   21613 non-null  int64
#  14  zipcode        21613 non-null  int64
#  15  lat            21613 non-null  float64
#  16  long           21613 non-null  float64
# ...

# %%
fig, ax = plt.subplots(figsize=(17,12))
x[["price"]].plot.hist(ax=ax)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
x_box = x.copy()

for col in x_box.columns:
    x_box[col] = (x_box[col] - x_box[col].min())/(x_box[col].max() - x_box[col].min())
fig, ax = plt.subplots(figsize=(17,12))
x_box.plot.box(ax=ax)
ax.grid()

# %%
fig, ax = plt.subplots(figsize=(17,12))
sns.heatmap(x.corr(), ax=ax, annot=True, cmap="Blues_r")
# Out:
# <AxesSubplot:>

# %%
x.drop(['sqft_living', 'sqft_living15'],axis=1,inplace=True )

# %%
fig, ax = plt.subplots(figsize=(17,12))
sns.heatmap(x.corr(), ax=ax, annot=True, cmap="Blues_r")
# Out:
# <AxesSubplot:>

# %%
x.loc[x['yr_renovated'] == 0, 'is_renovated'] = 0
x.loc[x['yr_renovated'] != 0, 'is_renovated'] = 1

# %%
x.loc[x['yr_renovated'] == 0, 'yr_renovated'] = x['yr_built']
x.drop('yr_built', axis=1, inplace=True)

# %%
x.head()
# Out:
#       price  bedrooms  bathrooms  sqft_lot  floors  waterfront  view  \
# 0  221900.0         3       1.00      5650     1.0           0     0
# 1  538000.0         3       2.25      7242     2.0           0     0
# 2  180000.0         2       1.00     10000     1.0           0     0
# 3  604000.0         4       3.00      5000     1.0           0     0
# 4  510000.0         3       2.00      8080     1.0           0     0
#
#    condition  grade  sqft_above  sqft_basement  yr_renovated  zipcode  \
# 0          3      7        1180              0          1955    98178
# 1          3      7        2170            400          1991    98125
# 2          3      6         770              0          1933    98028
# 3          5      7        1050            910          1965    98136
# 4          3      8        1680              0          1987    98074
#
#        lat     long  sqft_lot15  is_renovated
# 0  47.5112 -122.257        5650           0.0
# ...

# %%
from sklearn.preprocessing import LabelEncoder

zip_le = LabelEncoder()
x['zipcode'] = zip_le.fit_transform(x['zipcode'])

# %%
x.head()
# Out:
#       price  bedrooms  bathrooms  sqft_lot  floors  waterfront  view  \
# 0  221900.0         3       1.00      5650     1.0           0     0
# 1  538000.0         3       2.25      7242     2.0           0     0
# 2  180000.0         2       1.00     10000     1.0           0     0
# 3  604000.0         4       3.00      5000     1.0           0     0
# 4  510000.0         3       2.00      8080     1.0           0     0
#
#    condition  grade  sqft_above  sqft_basement  yr_renovated  zipcode  \
# 0          3      7        1180              0          1955       66
# 1          3      7        2170            400          1991       55
# 2          3      6         770              0          1933       16
# 3          5      7        1050            910          1965       58
# 4          3      8        1680              0          1987       37
#
#        lat     long  sqft_lot15  is_renovated
# 0  47.5112 -122.257        5650           0.0
# ...

# %%
fig, ax = plt.subplots(figsize=(17,12))
x.plot.scatter(x="lat", y="long", ax=ax, c="zipcode", cmap="rainbow")
# Out:
# <AxesSubplot:xlabel='lat', ylabel='long'>

# %%
x.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 17 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   price          21613 non-null  float64
#  1   bedrooms       21613 non-null  int64
#  2   bathrooms      21613 non-null  float64
#  3   sqft_lot       21613 non-null  int64
#  4   floors         21613 non-null  float64
#  5   waterfront     21613 non-null  int64
#  6   view           21613 non-null  int64
#  7   condition      21613 non-null  int64
#  8   grade          21613 non-null  int64
#  9   sqft_above     21613 non-null  int64
#  10  sqft_basement  21613 non-null  int64
#  11  yr_renovated   21613 non-null  int64
#  12  zipcode        21613 non-null  int64
#  13  lat            21613 non-null  float64
#  14  long           21613 non-null  float64
#  15  sqft_lot15     21613 non-null  int64
#  16  is_renovated   21613 non-null  float64
# dtypes: float64(6), int64(11)
# ...

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import *
from sklearn.metrics import *
from sklearn.preprocessing import PolynomialFeatures
from math import inf

# %%
X_columns = list(x.columns)
X_columns.remove('price')
X = x[X_columns].values
Y = x['price'].values

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.20)

# %%
params = {
    "fit_intercept": [True, False],
    "normalize": [True, False],
}

# %%
model = LinearRegression()
gc = GridSearchCV(model, params)
gc = gc.fit(X_train, Y_train)
gc.best_params_
# Out:
# {'fit_intercept': True, 'normalize': True}

# %%
Y_pred = gc.predict(X_test)
mse = mean_squared_error(Y_test, Y_pred)
r2 = r2_score(Y_test, Y_pred)
print("Mean squared error = ", mse)
print(f"R² = {r2*100:.2f}%")
# Out:
# Mean squared error =  39961129998.94442
# R² = 69.86%

# %%
pol = PolynomialFeatures(degree = 2)
X_train_pol = pol.fit_transform(X_train)
X_test_pol = pol.fit_transform(X_test)
X_train_pol.shape
# Out:
# (17290, 153)

# %%
model = LinearRegression()
gc = GridSearchCV(model, params)
gc = gc.fit(X_train_pol, Y_train)
gc.best_params_
# Out:
# {'fit_intercept': True, 'normalize': False}

# %%
Y_pred_pol = gc.predict(X_test_pol)
mse = mean_squared_error(Y_test, Y_pred_pol)
r2 = r2_score(Y_test, Y_pred_pol)
print("Mean squared error = ", mse)
print(f"R² = {r2*100:.2f}%")
print ('or' , f"R² = inf %")
# Out:
# Mean squared error =  25305788517.354015
# R² = 80.92%
# or R² = inf %

# %%
model = LinearRegression()
model.fit(X_train[:,1].reshape(-1,1),Y_train)
# Out:
# LinearRegression()
