# %%
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as mpl

a=pd.read_csv("titanic-passengers.csv",delimiter=';')
a
# Out:
#      PassengerId Survived  Pclass  \
# 0            343       No       2
# 1             76       No       3
# 2            641       No       3
# 3            568       No       3
# 4            672       No       1
# ..           ...      ...     ...
# 886           10      Yes       2
# 887           61       No       3
# 888          535       No       3
# 889          102       No       3
# 890          428      Yes       2
#
#                                                   Name     Sex   Age  SibSp  \
# 0                           Collander, Mr. Erik Gustaf    male  28.0      0
# 1                              Moen, Mr. Sigurd Hansen    male  25.0      0
# 2                               Jensen, Mr. Hans Peder    male  20.0      0
# 3          Palsson, Mrs. Nils (Alma Cornelia Berglund)  female  29.0      0
# 4                               Davidson, Mr. Thornton    male  31.0      1
# ..                                                 ...     ...   ...    ...
# 886                Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# 887                              Sirayanian, Mr. Orsen    male  22.0      0
# 888                                Cacic, Miss. Marija  female  30.0      0
# 889                   Petroff, Mr. Pastcho ("Pentcho")    male   NaN      0
# 890  Phillips, Miss. Kate Florence ("Mrs Kate Louis...  female  19.0      0
#
#      Parch      Ticket     Fare  Cabin Embarked
# 0        0      248740  13.0000    NaN        S
# 1        0      348123   7.6500  F G73        S
# 2        0      350050   7.8542    NaN        S
# 3        4      349909  21.0750    NaN        S
# 4        0  F.C. 12750  52.0000    B71        S
# ..     ...         ...      ...    ...      ...
# 886      0      237736  30.0708    NaN        C
# 887      0        2669   7.2292    NaN        C
# 888      0      315084   8.6625    NaN        S
# 889      0      349215   7.8958    NaN        S
# 890      0      250655  26.0000    NaN        S
#
# [891 rows x 12 columns]

# %%
print(a.isnull().sum())
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
a['Age'].fillna( a["Age"].mean())
a
# Out:
#      PassengerId Survived  Pclass  \
# 0            343       No       2
# 1             76       No       3
# 2            641       No       3
# 3            568       No       3
# 4            672       No       1
# ..           ...      ...     ...
# 886           10      Yes       2
# 887           61       No       3
# 888          535       No       3
# 889          102       No       3
# 890          428      Yes       2
#
#                                                   Name     Sex   Age  SibSp  \
# 0                           Collander, Mr. Erik Gustaf    male  28.0      0
# 1                              Moen, Mr. Sigurd Hansen    male  25.0      0
# 2                               Jensen, Mr. Hans Peder    male  20.0      0
# 3          Palsson, Mrs. Nils (Alma Cornelia Berglund)  female  29.0      0
# 4                               Davidson, Mr. Thornton    male  31.0      1
# ..                                                 ...     ...   ...    ...
# 886                Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# 887                              Sirayanian, Mr. Orsen    male  22.0      0
# 888                                Cacic, Miss. Marija  female  30.0      0
# 889                   Petroff, Mr. Pastcho ("Pentcho")    male   NaN      0
# 890  Phillips, Miss. Kate Florence ("Mrs Kate Louis...  female  19.0      0
#
#      Parch      Ticket     Fare  Cabin Embarked
# 0        0      248740  13.0000    NaN        S
# 1        0      348123   7.6500  F G73        S
# 2        0      350050   7.8542    NaN        S
# 3        4      349909  21.0750    NaN        S
# 4        0  F.C. 12750  52.0000    B71        S
# ..     ...         ...      ...    ...      ...
# 886      0      237736  30.0708    NaN        C
# 887      0        2669   7.2292    NaN        C
# 888      0      315084   8.6625    NaN        S
# 889      0      349215   7.8958    NaN        S
# 890      0      250655  26.0000    NaN        S
#
# [891 rows x 12 columns]

# %%
a.drop('Cabin',axis = 1 ,inplace = True)

# %%
td = {

                    "Capt":       "Officer",

                    "Col":        "Officer",

                    "Major":      "Officer",

                      "Dr":         "Officer",

                    "Rev":        "Officer",

                    "Jonkheer":   "Royalty",

                    "Don":        "Royalty",

                    "Sir" :       "Royalty",

                   "Lady" :      "Royalty",

                  "the Countess": "Royalty",

                    "Dona":       "Royalty",

                    "Mme":        "Miss",

                    "Mlle":       "Miss",

                    "Miss" :      "Miss",

                    "Ms":         "Mrs",

                    "Mr" :        "Mrs",

                    "Mrs" :       "Mrs",

                    "Master" :    "Master"

                    }

# %%
def plot_correlation_map(df):
    corr = df.corr()
    s , ax = mpl.subplots( figsize =( 17 , 17))
    cmap = sns.diverging_palette( 220 , 10 , as_cmap = True)
    s = sns.heatmap(
        corr, 
        cmap = cmap,
        square=True, 
        cbar_kws={'shrink' : .9}, 
        ax=ax, 
        annot = True, 
        annot_kws = {'fontsize' : 12})

    
plot_correlation_map(a)

# %%
noms = a['Name'].values
a['Title']= list(map(lambda x : x.split(",")[1].split('.')[0].strip(), noms))
a['Title'].replace(td, inplace=True)
a['Title'].values
# Out:
# array(['Mrs', 'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Miss', 'Mrs',
#        'Mrs', 'Mrs', 'Miss', 'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Mrs',
#        'Mrs', 'Mrs', 'Miss', 'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Mrs',
#        'Officer', 'Mrs', 'Miss', 'Mrs', 'Mrs', 'Mrs', 'Officer', 'Mrs',
#        'Royalty', 'Mrs', 'Mrs', 'Mrs', 'Miss', 'Miss', 'Mrs', 'Mrs',
#        'Miss', 'Mrs', 'Miss', 'Mrs', 'Master', 'Officer', 'Mrs', 'Mrs',
#        'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Mrs',
#        'Mrs', 'Mrs', 'Miss', 'Miss', 'Master', 'Miss', 'Mrs', 'Officer',
#        'Mrs', 'Mrs', 'Mrs', 'Miss', 'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Miss',
#        'Mrs', 'Miss', 'Miss', 'Miss', 'Mrs', 'Master', 'Mrs', 'Mrs',
#        'Mrs', 'Mrs', 'Miss', 'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Miss', 'Mrs',
#        'Mrs', 'Mrs', 'Mrs', 'Miss', 'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Master',
#        'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Miss', 'Mrs', 'Mrs', 'Master',
#        'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Miss',
#        'Mrs', 'Mrs', 'Officer', 'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Mrs',
#        'Mrs', 'Miss', 'Mrs', 'Mrs', 'Miss', 'Mrs', 'Mrs', 'Miss', 'Mrs',
#        'Miss', 'Mrs', 'Miss', 'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Miss',
#        'Mrs', 'Mrs', 'Miss', 'Mrs', 'Mrs', 'Miss', 'Mrs', 'Mrs', 'Mrs',
#        'Miss', 'Master', 'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Miss',
#        'Master', 'Miss', 'Mrs', 'Miss', 'Mrs', 'Mrs', 'Mrs', 'Officer',
#        'Mrs', 'Miss', 'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Mrs',
#        'Mrs', 'Mrs', 'Miss', 'Mrs', 'Mrs', 'Mrs', 'Master', 'Mrs', 'Mrs',
#        'Miss', 'Mrs', 'Miss', 'Miss', 'Mrs', 'Miss', 'Mrs', 'Mrs', 'Mrs',
#        'Mrs', 'Miss', 'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Miss', 'Miss', 'Mrs',
#        'Mrs', 'Miss', 'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Master', 'Mrs', 'Mrs',
#        'Mrs', 'Mrs', 'Mrs', 'Miss', 'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Miss',
#        'Mrs', 'Miss', 'Miss', 'Mrs', 'Mrs', 'Master', 'Miss', 'Mrs',
#        'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Miss',
#        'Miss', 'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Mrs',
#        'Miss', 'Miss', 'Mrs', 'Mrs', 'Master', 'Miss', 'Mrs', 'Mrs',
#        'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Officer', 'Mrs', 'Mrs', 'Miss', 'Mrs',
#        'Mrs', 'Mrs', 'Miss', 'Mrs', 'Mrs', 'Miss', 'Mrs', 'Miss', 'Miss',
#        'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Miss', 'Mrs', 'Mrs', 'Mrs',
#        'Mrs', 'Miss', 'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Miss', 'Miss',
#        'Mrs', 'Mrs', 'Master', 'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Mrs',
#        'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Miss', 'Mrs', 'Miss', 'Mrs',
#        'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Miss', 'Mrs', 'Mrs', 'Mrs', 'Miss',
#        'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Miss',
#        'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Miss', 'Miss', 'Mrs',
#        'Mrs', 'Mrs', 'Mrs', 'Miss', 'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Miss',
#        'Mrs', 'Miss', 'Miss', 'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Miss', 'Mrs',
#        'Master', 'Mrs', 'Mrs', 'Miss', 'Mrs', 'Mrs', 'Miss', 'Mrs',
#        'Miss', 'Mrs', 'Miss', 'Miss', 'Mrs', 'Miss', 'Miss', 'Mrs',
#        'Miss', 'Mrs', 'Miss', 'Mrs', 'Mrs', 'Mrs', 'Miss', 'Mrs',
#        'Master', 'Mrs', 'Miss', 'Miss', 'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Mrs',
#        'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Royalty', 'Miss', 'Mrs', 'Mrs',
#        'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Miss', 'Master',
#        'Mrs', 'Mrs', 'Master', 'Mrs', 'Miss', 'Mrs', 'Mrs', 'Mrs', 'Mrs',
#        'Mrs', 'Mrs', 'Officer', 'Officer', 'Mrs', 'Mrs', 'Master', 'Mrs',
#        'Miss', 'Mrs', 'Master', 'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Mrs',
#        'Mrs', 'Mrs', 'Miss', 'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Miss',
#        'Miss', 'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Master', 'Mrs', 'Mrs', 'Miss',
#        'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Mrs',
#        'Mrs', 'Mrs', 'Miss', 'Mrs', 'Miss', 'Miss', 'Master', 'Mrs',
#        'Mrs', 'Mrs', 'Mrs', 'Miss', 'Mrs', 'Mrs', 'Miss', 'Mrs', 'Mrs',
#        'Mrs', 'Miss', 'Miss', 'Mrs', 'Mrs', 'Miss', 'Mrs', 'Mrs', 'Miss',
#        'Mrs', 'Miss', 'Miss', 'Miss', 'Mrs', 'Mrs', 'Mrs', 'Miss', 'Miss',
#        'Mrs', 'Miss', 'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Mrs',
#        'Miss', 'Mrs', 'Master', 'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Mrs',
#        'Master', 'Miss', 'Mrs', 'Mrs', 'Royalty', 'Mrs', 'Mrs', 'Mrs',
#        'Miss', 'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Miss',
#        'Mrs', 'Mrs', 'Mrs', 'Miss', 'Master', 'Mrs', 'Mrs', 'Mrs', 'Mrs',
#        'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Master', 'Mrs', 'Mrs',
#        'Mrs', 'Mrs', 'Mrs', 'Miss', 'Mrs', 'Miss', 'Mrs', 'Mrs', 'Mrs',
#        'Mrs', 'Mrs', 'Mrs', 'Master', 'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Mrs',
#        'Miss', 'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Miss', 'Miss', 'Miss', 'Miss',
#        'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Master', 'Mrs', 'Master', 'Mrs',
#        'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Miss', 'Mrs', 'Mrs',
#        'Master', 'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Miss', 'Miss',
#        'Mrs', 'Miss', 'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Mrs',
#        'Miss', 'Mrs', 'Miss', 'Mrs', 'Mrs', 'Master', 'Mrs', 'Master',
#        'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Mrs',
#        'Mrs', 'Mrs', 'Mrs', 'Master', 'Mrs', 'Mrs', 'Miss', 'Mrs', 'Mrs',
#        'Miss', 'Miss', 'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Mrs',
#        'Mrs', 'Mrs', 'Mrs', 'Miss', 'Mrs', 'Mrs', 'Mrs', 'Miss', 'Mrs',
#        'Mrs', 'Royalty', 'Mrs', 'Mrs', 'Miss', 'Miss', 'Mrs', 'Miss',
#        'Mrs', 'Mrs', 'Mrs', 'Miss', 'Mrs', 'Mrs', 'Miss', 'Mrs', 'Mrs',
#        'Mrs', 'Mrs', 'Miss', 'Miss', 'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Mrs',
#        'Mrs', 'Mrs', 'Mrs', 'Miss', 'Mrs', 'Officer', 'Mrs', 'Mrs', 'Mrs',
#        'Mrs', 'Mrs', 'Master', 'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Officer',
#        'Mrs', 'Master', 'Mrs', 'Mrs', 'Mrs', 'Miss', 'Mrs', 'Mrs',
#        'Officer', 'Mrs', 'Mrs', 'Mrs', 'Master', 'Mrs', 'Officer', 'Miss',
#        'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Miss', 'Officer', 'Mrs', 'Mrs',
#        'Mrs', 'Mrs', 'Mrs', 'Miss', 'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Mrs',
#        'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Officer', 'Mrs', 'Mrs', 'Mrs',
#        'Mrs', 'Mrs', 'Mrs', 'Officer', 'Mrs', 'Mrs', 'Mrs', 'Officer',
#        'Miss', 'Miss', 'Mrs', 'Royalty', 'Mrs', 'Miss', 'Mrs', 'Mrs',
#        'Mrs', 'Mrs', 'Mrs', 'Miss', 'Master', 'Mrs', 'Mrs', 'Mrs', 'Mrs',
#        'Miss', 'Miss', 'Mrs', 'Mrs', 'Miss', 'Mrs', 'Mrs', 'Mrs', 'Miss',
#        'Mrs', 'Miss', 'Mrs', 'Miss', 'Mrs', 'Miss', 'Mrs', 'Mrs', 'Mrs',
#        'Mrs', 'Mrs', 'Miss', 'Mrs', 'Miss', 'Miss', 'Mrs', 'Mrs', 'Miss',
#        'Mrs', 'Miss', 'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Mrs',
#        'Miss', 'Master', 'Master', 'Mrs', 'Master', 'Mrs', 'Miss', 'Miss',
#        'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Miss', 'Miss', 'Mrs', 'Mrs',
#        'Miss', 'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Miss',
#        'Miss', 'Miss', 'Mrs', 'Mrs', 'Miss', 'Mrs', 'Mrs', 'Miss', 'Mrs',
#        'Miss', 'Mrs', 'Mrs', 'Mrs', 'Miss', 'Mrs', 'Mrs', 'Miss', 'Mrs',
#        'Mrs', 'Miss', 'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Master', 'Mrs',
#        'Miss', 'Mrs', 'Miss', 'Mrs', 'Miss', 'Mrs', 'Mrs', 'Miss', 'Mrs',
#        'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Mrs', 'Master', 'Mrs',
#        'Miss', 'Mrs', 'Miss', 'Miss', 'Miss', 'Mrs', 'Mrs', 'Mrs', 'Mrs',
#        'Officer', 'Mrs', 'Mrs', 'Miss', 'Mrs', 'Miss'], dtype=object)

# %%
a['Fam'] = (a['Parch'] + a['SibSp'])
a['Fam']
# Out:
# 0      0
# 1      0
# 2      0
# 3      4
# 4      1
#       ..
# 886    1
# 887    0
# 888    0
# 889    0
# 890    0
# Name: Fam, Length: 891, dtype: int64
